# %%
# !pip install -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt
# !pip install ai-edge-torch-nightly
# Out:
# Looking in links: https://download.pytorch.org/whl/torch/, https://download.pytorch.org/whl/torchvision/, https://download.pytorch.org/whl/torchaudio/
# Requirement already satisfied: torch==2.4.0+cpu in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (2.4.0+cpu)
# Requirement already satisfied: torchvision==0.19.0+cpu in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 4)) (0.19.0+cpu)
# Requirement already satisfied: torchaudio==2.4.0+cpu in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 6)) (2.4.0+cpu)
# Requirement already satisfied: torch_xla==2.4.0 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: tf-nightly>=2.18.0.dev20240905 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.18.0.dev20240925)
# Requirement already satisfied: ai-edge-litert-nightly in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 10)) (1.0.1.dev20240928)
# Requirement already satisfied: ai-edge-quantizer-nightly in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 11)) (0.0.1.dev20240929)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 12)) (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 13)) (1.26.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 14)) (0.9.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 15)) (0.4.5)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 17)) (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (2024.6.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.19.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 4)) (10.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: cloud-tpu-client>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (0.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (1.64.1)
# Requirement already satisfied: tb-nightly~=2.18.0.a in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.18.0a20240925)
# Requirement already satisfied: keras-nightly>=3.2.0.dev in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.6.0.dev2024092903)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.37.1)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from ai-edge-quantizer-nightly->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 11)) (4.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 16)) (4.66.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 17)) (0.24.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 17)) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 17)) (0.19.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.44.0)
# Requirement already satisfied: google-api-python-client==1.8.0 in /usr/local/lib/python3.10/dist-packages (from cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (1.8.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (4.1.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (0.22.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: google-api-core<2dev,>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (1.34.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0+cpu->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (1.65.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.9.2->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch_xla==2.4.0->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 7)) (3.1.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240905->-r https://raw.githubusercontent.com/google-ai-edge/ai-edge-torch/main/requirements.txt (line 9)) (0.1.2)
# Collecting ai-edge-torch-nightly
#   Using cached ai_edge_torch_nightly-0.3.0.dev20240928-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (1.13.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (0.4.5)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (0.9.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (2.4.0+cpu)
# Requirement already satisfied: torch-xla>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (2.4.0)
# Requirement already satisfied: tf-nightly>=2.18.0.dev20240722 in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (2.18.0.dev20240925)
# Requirement already satisfied: ai-edge-litert-nightly in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (1.0.1.dev20240928)
# Requirement already satisfied: ai-edge-quantizer-nightly in /usr/local/lib/python3.10/dist-packages (from ai-edge-torch-nightly) (0.0.1.dev20240929)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (1.64.1)
# Requirement already satisfied: tb-nightly~=2.18.0.a in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2.18.0a20240925)
# Requirement already satisfied: keras-nightly>=3.2.0.dev in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.6.0.dev2024092903)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->ai-edge-torch-nightly) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->ai-edge-torch-nightly) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->ai-edge-torch-nightly) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->ai-edge-torch-nightly) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->ai-edge-torch-nightly) (2024.6.1)
# Requirement already satisfied: cloud-tpu-client>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from torch-xla>=2.4.0->ai-edge-torch-nightly) (0.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from torch-xla>=2.4.0->ai-edge-torch-nightly) (6.0.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from ai-edge-quantizer-nightly->ai-edge-torch-nightly) (4.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.44.0)
# Requirement already satisfied: google-api-python-client==1.8.0 in /usr/local/lib/python3.10/dist-packages (from cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (1.8.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (4.1.3)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (0.22.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (0.2.0)
# Requirement already satisfied: google-api-core<2dev,>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (1.34.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (3.0.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tb-nightly~=2.18.0.a->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.4.0->ai-edge-torch-nightly) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.4.0->ai-edge-torch-nightly) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (2.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<2dev,>=1.13.0->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (1.65.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.4.1->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (5.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.9.2->google-api-python-client==1.8.0->cloud-tpu-client>=0.10.0->torch-xla>=2.4.0->ai-edge-torch-nightly) (3.1.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly>=3.2.0.dev->tf-nightly>=2.18.0.dev20240722->ai-edge-torch-nightly) (0.1.2)
# Using cached ai_edge_torch_nightly-0.3.0.dev20240928-py3-none-any.whl (291 kB)
# Installing collected packages: ai-edge-torch-nightly
# Successfully installed ai-edge-torch-nightly-0.3.0.dev20240928

# %%
# download file and save here: https://github.com/google-ai-edge/ai-edge-torch/blob/main/ai_edge_torch/generative/quantize/quant_recipes.py

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchaudio
class M5(nn.Module):
    def __init__(self, n_input=1, n_output=35, stride=16, n_channel=32):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=80, stride=stride)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 2 * n_channel, kernel_size=3)
        self.pool4 = nn.MaxPool1d(4)
        self.fc1 = nn.Linear(2 * n_channel, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.pool4(x)
        x = F.avg_pool1d(x, x.shape[-1])
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        return F.log_softmax(x, dim=2)

# load model from pt
model = torch.load('model.pt')
# Out:
# <ipython-input-19-d0b739a17c68>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load('model.pt')

# %%
import ai_edge_torch
sample_inputs = (torch.rand((256, 1, 8000)),)
edge_model = ai_edge_torch.convert(model.eval(), sample_inputs)

# %%
import sys
sys.path.append('/content')
import quant_recipes
quant_config = quant_recipes.full_int8_dynamic_recipe()
edge_model_compressed = ai_edge_torch.convert(
    model.eval(), sample_inputs, quant_config=quant_config
)

# %%
edge_model_compressed.export('model.tflite')

# %%
from torchaudio.datasets import SPEECHCOMMANDS
import os


class SubsetSC(SPEECHCOMMANDS):
    def __init__(self, subset: str = None, include_labels=None, silence_ratio=0.1, unknown_ratio=0.1):
        super().__init__("./", download=True)

        def load_list(filename):
            filepath = os.path.join(self._path, filename)
            with open(filepath) as fileobj:
                return [os.path.normpath(os.path.join(self._path, line.strip())) for line in fileobj]

        if subset == "validation":
            self._walker = load_list("validation_list.txt")
        elif subset == "testing":
            self._walker = load_list("testing_list.txt")
        elif subset == "training":
            excludes = load_list("validation_list.txt") + load_list("testing_list.txt")
            excludes = set(excludes)
            self._walker = [w for w in self._walker if w not in excludes]

        # 如果指定了 include_labels, 过滤 _walker 中的词
        if include_labels is not None:
            self._walker = [w for w in self._walker if self._get_label(w) in include_labels]

    def _get_label(self, filepath):
        # 根据文件路径推断出标签。一般文件路径中包含了标签名
        return os.path.normpath(filepath).split(os.sep)[-2]


# 你只想要的几个词，例如 "yes", "no", "up", "down"
selected_words = ["yes", "no"]
# selected_words = ["down", "go", "left", "no", "off", "on", "right", "stop", "up", "yes"]

# 创建仅包含选定词的训练和测试集
train_set = SubsetSC("training", include_labels=selected_words)
test_set = SubsetSC("testing", include_labels=selected_words)

waveform, sample_rate, label, speaker_id, utterance_number = train_set[0]

# %%
labels = sorted(list(set(datapoint[2] for datapoint in train_set)))

def label_to_index(word):
    # Return the position of the word in labels
    return torch.tensor(labels.index(word))


def index_to_label(index):
    # Return the word corresponding to the index in labels
    # This is the inverse of label_to_index
    return labels[index]

def pad_sequence(batch):
    # Make all tensor in a batch the same length by padding with zeros
    batch = [item.t() for item in batch]
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)
    return batch.permute(0, 2, 1)


def collate_fn(batch):

    # A data tuple has the form:
    # waveform, sample_rate, label, speaker_id, utterance_number

    tensors, targets = [], []

    # Gather in lists, and encode labels as indices
    for waveform, _, label, *_ in batch:
        tensors += [waveform]
        targets += [label_to_index(label)]

    # Group the list of tensors into a batched tensor
    tensors = pad_sequence(tensors)
    targets = torch.stack(targets)

    return tensors, targets


batch_size = 256

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

if device == "cuda":
    num_workers = 1
    pin_memory = True
else:
    num_workers = 0
    pin_memory = False

train_loader = torch.utils.data.DataLoader(
    train_set,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)
test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)

pbar_update = 1 / (len(train_loader) + len(test_loader))

def number_of_correct(pred, target):
    # count number of correct predictions
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):
    # find most likely label index for each element in the batch
    # print(tensor)
    tensor = torch.tensor(tensor)
    return tensor.argmax(dim=-1)

new_sample_rate = 8000
transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)

# %%
from tqdm import tqdm
n_epoch = 30

with tqdm(total=n_epoch) as pbar:
  pass

def test(model, epoch):
    # model.eval()
    correct = 0
    for data, target in test_loader:

        data = data.to(device)
        target = target.to(device)

        # apply transform and model on whole batch directly on device
        data = transform(data)
        try:
          # Code that might raise an error
          output = model(data)
          pred = get_likely_index(output)
          correct += number_of_correct(pred, target)

          # update progress bar
          pbar.update(pbar_update)
        except Exception as e:
          # Code to handle the error or simply pass
          print(f"Error: {e}")
          continue  # This will skip the error and continue execution

    print(f"\nTest Epoch: {epoch}\tAccuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
test(model, 1)
# Out:
# <ipython-input-6-ee1663fd04a4>:78: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor = torch.tensor(tensor)
# Test Epoch: 1	Accuracy: 244/824 (30%)
#
#
# Test Epoch: 1	Accuracy: 494/824 (60%)
#
#
# Test Epoch: 1	Accuracy: 743/824 (90%)
#
#
# Test Epoch: 1	Accuracy: 797/824 (97%)

# %%
import ai_edge_torch
test(edge_model_compressed, 1)
# Out:
# Error: Cannot set tensor: Tensor is unallocated. Try calling allocate_tensors() first
#
# Test Epoch: 1	Accuracy: 744/824 (90%)

# %%
# !apt-get update  # <-- run this if you get install errors
# !apt-get -qq install xxd
# !echo "Exporting model. Model size (in bytes):"
# !stat --printf="%s" model.tflite
# !xxd -i model.tflite > model.txt # xxd is just used to create a hex dump from model file
# Out:
# Exporting model. Model size (in bytes):
# 32728
